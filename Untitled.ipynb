# %%
#!./run.sh configs/cityscapes_fed_oracle.txt
#import wandb
#wandb.login()
#wandb.init(project="Second_trial", entity="alessandro-fella-1")

#Scrivania/PROVA/LADD/src/utils/args.py
#Scrivania/PROVA/LADD/src/utils/style_transfer.py
#Scrivania/PROVA/LADD/src/dataset/target/target_dataset.py
#Scrivania/PROVA/LADD/src/dataset/preprocess.py
#Scrivania/PROVA/LADD/src/dataset/transform_cv2.py
#Scrivania/PROVA/LADD/src/dataset/transform.py

# %%
import torch
torch.cuda.empty_cache()

# %%
# !./run.sh configs/cityscapes_fed_oracle.txt
# Out:
# GPUs in usage: 0
# Running federated oracle experiment...
# Setting up distributed...
# Let's use 1 GPUs!
# Done
# Initializing wandb...
# wandb: Currently logged in as: alessandro-fella-1. Use `wandb login --relogin` to force relogin
# wandb: ERROR Failed to sample metric: Not Supported
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /home/utente/Scrivania/PROVA/LADD/wandb/run-20221206_181507-1w9reu70
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deeplabv3_r5_e1_cl5_heterogeneous_lr0.05_bs16_rs42_cityscapes_fed_oracle
# wandb: ⭐️ View project at https://wandb.ai/alessandro-fella-1/federated_cityscapes
# wandb: 🚀 View run at https://wandb.ai/alessandro-fella-1/federated_cityscapes/runs/1w9reu70
# Done.
# Setting up the random seed for reproducibility...
# Done.
# Initializing model...
# Done.
# Initializing datasets...
# Done.
# Initializing clients...
# Done.
# Initializing server...
# Running without server optimizer
# ...
